# %% [markdown]
# ## Q1

# %% [markdown]
# ![image.png](attachment:7bc884ec-5713-497a-b66a-53837d76d1d9.png)

# %%
playlist = ["Thriller","Back in Black","Rumours"]
playlist.append("The Bodyguard")
print(playlist)
playlist[1] = "Bat Out of Hell"
short_playlist = playlist[:2]
print(short_playlist)
# Out:
# ['Thriller', 'Back in Black', 'Rumours', 'The Bodyguard']
# ['Thriller', 'Bat Out of Hell']

# %% [markdown]
# ## Q2

# %% [markdown]
# ![image.png](attachment:c9ec8e81-542c-4a0e-b817-22b9929c3697.png)

# %%
leaderboard = [("Alice", 9500), ("Bob", 8200), ("Charlie", 10000)]
new_score = ("Bob", 8800)
leaderboard[1] = new_score
leaderboard
# Out:
# [('Alice', 9500), ('Bob', 8800), ('Charlie', 10000)]

# %% [markdown]
# ## Q3

# %% [markdown]
# ![image.png](attachment:4f969d03-0680-4c63-9a91-306b8416f757.png)

# %%
inventory = [("Laptops", 10, 1000), ("Mice", 50, 20), ("Keyboards", 30, 50)]
total_value = 0 
for item in inventory:
    item_value = item[1] * item[2]
    total_value = total_value + item_value 
total_value

#########################################################################################
inventory = [("Laptops", 10, 1000), ("Mice", 50, 20), ("Keyboards", 30, 50)]
total_value = 0 
for item,quantity,price in inventory:
    total_value += quantity * price
total_value
# Out:
# 12500
